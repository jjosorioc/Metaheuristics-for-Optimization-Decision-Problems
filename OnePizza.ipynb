# %% [markdown]
# # Metaheuristics for Optimization/Decision Problems

# %% [markdown]
# 1. **Solution Representation**:
#    The solution representation for this problem can be a set of INGREDIENTS that will be included in the pizza. Each ingredient appears only once in the set, and the order of ingredients doesn't matter. This set represents the ingredients to be included in the pizza.
#    I: Set of INGREDIENTS.
#
# 2. **Neighborhood/Mutation**:
#    - **Add/Remove Ingredient**: With a certain probability, randomly select an ingredient from the set of all possible INGREDIENTS. If the selected ingredient is not already in the solution, add it. If the selected ingredient is already in the solution, remove it.
#
# 3. **Crossover Functions**:
#    For crossover, we can use a one-point crossover approach. However, since we're dealing with sets, the concept of crossover becomes a bit different. We can combine INGREDIENTS from both parent sets to create two child sets, ensuring that there are no duplicate INGREDIENTS in the offspring.
#
# 4. **Hard Constraints**:
#    There's one hard constraint for this problem:
#    - **Non-Empty Solution**: Ensure that the solution set contains at least one ingredient. If, after mutation or crossover, the solution becomes empty, add a randomly selected ingredient from the set of all possible INGREDIENTS to the solution to maintain its non-emptiness. This ensures that there is always at least one ingredient on the pizza, as an empty pizza would not attract any clients.
#
# 5. **Evaluation Functions**:
#    The evaluation function calculates the fitness of a solution by counting how many clients will visit the pizzeria with that solution. To do this, iterate over each client and check if all the INGREDIENTS they like are present in the solution and none of the ingredients they dislike are present. Increment a counter for each client that meets these conditions, and return the total count as the fitness score for the solution.

# %%
import random
import time
import copy
import numpy as np
import warnings
warnings.filterwarnings('ignore')


def read_input_file(file_path) ->tuple[int, list]:
    """Reads the input

    Args:
        file_path (str): File path to the input file

    Returns:
        tuple: Number of clients, list of tuples (likes, dislikes)
    """
    with open(file_path, 'r') as file:
        # first line, 1 <= C <= 10^5 potential clients
        num_clients = int(file.readline().strip())

        # following 2*C lines, list of tuples (likes, dislikes)
        client_preferences = []
        for _ in range(num_clients):
            likes = file.readline().strip().split()[1:] # 1 ≤ L ≤ 5 likes
            dislikes = file.readline().strip().split()[1:] # 0 ≤ D ≤ 5 dislikes
            client_preferences.append((likes, dislikes))
    return num_clients, client_preferences

# Input
file_path = 'example1.in'

num_clients, CLIENT_PREFERENCES = read_input_file(file_path)
print("Number of Clients:", num_clients)
for likes, dislikes in CLIENT_PREFERENCES:
    print("Likes:", likes)
    print("Dislikes:", dislikes)
# Out:
# Number of Clients: 3
# Likes: ['cheese', 'peppers']
# Dislikes: []
# Likes: ['basil']
# Dislikes: ['pineapple']
# Likes: ['mushrooms', 'tomatoes']
# Dislikes: ['basil']

# %%
# Returns a list with all the ingredients
def get_all_ingredients() -> set[str]:
    """Return a set with all the ingredients

    Returns:
        set[str]: All the ingredients.
    """
    
    all_ingredients = set()
    for client in CLIENT_PREFERENCES:
        all_ingredients.update(client[0])
        all_ingredients.update(client[1])
    return all_ingredients

def random_solution() -> set[str]:
    """Return a random solution
    Returns:
        set[str]: A random solution.
    """
    return set(random.sample(INGREDIENTS, random.randint(1, len(INGREDIENTS))))

# Scoring
def evaluate_solution(state) -> int:
    """Evaluate a state

    Args:
        solution (set): Current state

    Returns:
        int: Score
    """
    score = 0
    for client in CLIENT_PREFERENCES:
        likes = set(client[0])
        dislikes = set(client[1])
        # all the ingredients they like are on the pizza, none of the ingredients they dislike are on the pizza
        if likes.issubset(state) and not any(dislike in state for dislike in dislikes):
            score += 1
    return score


INGREDIENTS = get_all_ingredients()

INITIAL_SOLUTION = random_solution()
INITIAL_SCORE = evaluate_solution( INITIAL_SOLUTION)
print("Initial Solution:", INITIAL_SOLUTION)
print("Score:", INITIAL_SCORE)
# Out:
# Initial Solution: {'cheese', 'tomatoes'}
# Score: 0

# %%
# Submission - Number of ingredients on the pizza followed by unordered list of them, without repetitions
output = f"{len(INITIAL_SOLUTION)} {' '.join(INITIAL_SOLUTION)}"
print(output)
# Out:
# 2 cheese tomatoes

# %%
# MUTATION AND CROSSOVER
def mutate_solution(state) -> list[str]:
    """Mutation and crossover

    Args:
        state: Current state

    Returns:
        list: Next state
    """
    mutated_solution = state.copy()
    mutated_solution = list(state)  # Ensure mutated_solution is a list
    # Remove or add an ingredient randomly
    if random.random() < 0.5:  # Remove
        if mutated_solution:
            mutated_solution.remove(random.choice(mutated_solution))
    else:  # Add
        available_ingredients = [i for i in INGREDIENTS if i not in mutated_solution]
        if available_ingredients:
            ingredient_to_add = random.choice(available_ingredients)
            mutated_solution.append(ingredient_to_add)

    if mutated_solution == []:
        return mutate_solution(mutated_solution)
    return mutated_solution

# %%
mutated_solution = mutate_solution(INITIAL_SOLUTION)
mutated_score = evaluate_solution(mutated_solution)
print("Mutated Solution:", mutated_solution)
print("Score:", INITIAL_SCORE)
# Out:
# Mutated Solution: ['cheese', 'tomatoes', 'mushrooms']
# Score: 0

# %% [markdown]
# ## Random-restart Hill Climbing Algorithm

# %%
def get_hc_solution(num_iterations: int, log: bool = False) -> set[str] | list[str]:
    iteration = 0
    best_solution = INITIAL_SOLUTION
    best_score = evaluate_solution(best_solution)

    print(f"Initial Solution: {best_solution} with score {best_score}")

    while (iteration < num_iterations):
        iteration += 1
        
        neighbor_solution = mutate_solution(best_solution)
        neighbor_score = evaluate_solution(neighbor_solution)

        if (neighbor_score > best_score):
            best_solution = neighbor_solution
            best_score = neighbor_score
            iteration = 0
            if log:
                print(f"New best solution: {best_solution} with score {best_score}")

    print(f"Best Solution: {best_solution} with score {best_score}")
    return best_solution

# %%
print("Hill Climbing Solution:\n")
start_time = time.time()
final_solution = get_hc_solution(10000, log=True)
end_time = time.time()
output = f"\n{len(final_solution)} {' '.join(final_solution)}"
print(output)
print(f"Execution time: {end_time - start_time} seconds")
# Out:
# Hill Climbing Solution:
#
# Initial Solution: {'cheese', 'tomatoes'} with score 0
# New best solution: ['cheese', 'tomatoes', 'mushrooms'] with score 1
# New best solution: ['cheese', 'tomatoes', 'mushrooms', 'peppers'] with score 2
# Best Solution: ['cheese', 'tomatoes', 'mushrooms', 'peppers'] with score 2
#
# 4 cheese tomatoes mushrooms peppers
# Execution time: 0.03875470161437988 seconds

# %% [markdown]
# ## Simulated Annealing

# %%
# Simulated Annealing
def get_sa_solution(num_iterations: int, log: bool =False)-> set[str] | list[str]:
    iteration = 0
    temperature = 1000
    state = INITIAL_SOLUTION # Best solution after 'num_iterations' iterations without improvement
    score = evaluate_solution(state)

    best_solution = copy.deepcopy(state)
    best_score = score

    print(f"Init Solution:  {best_solution}, score: {best_score}")

    while iteration < num_iterations:
        temperature = temperature * 0.999  # Test with different cooling schedules
        iteration += 1

        neighbor_solution = mutate_solution(best_solution)
        neighbor_score = evaluate_solution( neighbor_solution)
        delta = neighbor_score - score
        if (delta > 0 or random.random() < np.exp(delta/temperature)):
            state = neighbor_solution
            score = neighbor_score

            if log:
                    print(f"Solution:       {best_solution}, score: {best_score},  Temp: {temperature}")

            if (score > best_score):
                best_solution = copy.deepcopy(state)
                best_score = score
                iteration = 0
                if log:
                    print(f"Best Solution:  {best_solution}, score: {best_score},  Temp: {temperature}, Prob: {np.exp(delta/temperature)}")

    print(f"Final Solution: {best_solution}, score: {best_score}")
    return best_solution

# %%
print("\nSimulated Annealing:\n")
start_time = time.time()
final_solution = get_sa_solution(10000, True)
end_time = time.time()
print(f"{len(final_solution)} {' '.join(final_solution)}")
print(f"Execution time: {end_time - start_time} seconds")
# Out:
# Simulated Annealing:
#
# Init Solution:  {'cheese', 'tomatoes'}, score: 0
# Solution:       {'cheese', 'tomatoes'}, score: 0,  Temp: 999.0
# Best Solution:  ['cheese', 'tomatoes', 'basil'], score: 1,  Temp: 999.0, Prob: 1.0010015021697125
# Solution:       ['cheese', 'tomatoes', 'basil'], score: 1,  Temp: 998.001
# Best Solution:  ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 998.001, Prob: 1.0010025051767273
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 997.0029989999999
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 996.005996001
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 995.0099900049989
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 994.014980014994
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 993.020965034979
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 992.027944069944
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 991.0359161258741
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 990.0448802097483
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 989.0548353295385
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 988.065780494209
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 987.0777147137147
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 986.090636999001
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 985.104546362002
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 984.11944181564
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 983.1353223738244
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 982.1521870514505
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 981.170034864399
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 980.1888648295346
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 979.2086759647051
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 978.2294672887404
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 977.2512378214516
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 976.2739865836302
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 975.2977125970466
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 974.3224148844496
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 973.3480924695651
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 972.3747443770956
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 971.4023696327184
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 970.4309672630857
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 969.4605362958226
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 968.4910757595268
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 967.5225846837673
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 966.5550620990834
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 965.5885070369843
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 964.6229185299474
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 963.6582956114174
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 962.6946373158061
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 961.7319426784902
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 960.7702107358117
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 959.8094405250758
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 958.8496310845508
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 957.8907814534662
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 956.9328906720127
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 955.9759577813408
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 955.0199818235594
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 954.0649618417359
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 953.1108968798942
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 952.1577859830143
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 951.2056281970313
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 950.2544225688342
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 949.3041681462654
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 948.3548639781192
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 947.406509114141
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 946.4591026050269
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 945.512643502422
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 944.5671308589195
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 943.6225637280606
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 942.6789411643326
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 941.7362622231683
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 940.7945259609452
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 939.8537314349842
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 938.9138777035492
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 937.9749638258457
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 937.0369888620199
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 936.0999518731579
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 935.1638519212847
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 934.2286880693634
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 933.2944593812941
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 932.3611649219129
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 931.428803756991
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 930.497374953234
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 929.5668775782808
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 928.6373107007025
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 927.7086733900019
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 926.7809647166118
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 925.8541837518952
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 924.9283295681433
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 924.0034012385752
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 923.0793978373366
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 922.1563184394993
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 921.2341621210597
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 920.3129279589386
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 919.3926150309798
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 918.4732224159487
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 917.5547491935328
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp:
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.055846859493872476
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.055679486400122484
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05562380691372236
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05551261492370183
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.055235606420383915
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05507006525270641
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05501499518745371
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05479526507667005
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.054685729341781786
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.054576412568827566
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05452183615625874
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05446731432010248
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.0543584341587766
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05397906474613871
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.053817289435115455
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05370970867353466
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.053655998964861125
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.053548740622930364
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.053334866738740966
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05322825034013023
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05290967819807765
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.052856768519879575
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05248787928424132
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05243539140495708
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.052278242484481034
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05217373827775456
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.052121564539476806
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.051913390802271996
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05186147741146972
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05175780631812419
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05170604851180607
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05165434246329426
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05155108543271014
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05149953434727743
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05129384500114777
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05119130860499047
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.051140117296385484
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.0510889771790891
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05093586346339438
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05088492759993099
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05068169299560804
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05052979991101851
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05047927011110749
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.050428790840996385
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05037836205015539
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.050277655704417126
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.05022737804871271
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.049926766187296724
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.049876839421109424
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04977713561910663
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04972735848348752
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.049528747214844765
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04947921846762992
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04942973924916229
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04933092920040321
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.049281598271202806
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.049232316672931604
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04913390127190241
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.048986646920656615
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04888872261346222
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.048790994056957915
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04864476739897822
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04859612263157924
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04849897898243871
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.048450480003456274
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04835362749392936
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.048305273866435426
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04820871162397642
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.048160502912352444
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04801616583696363
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04787226133993408
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04782438907859415
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.047681059336701206
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04758574489908714
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04734829155642112
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.047253642321599836
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.047159182290598956
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04706491108520005
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.046970828327940736
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.046876933642113185
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04683005670847107
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.046643017274704046
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.046596374257429345
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04654977788317192
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.046456724877183456
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.0462249053557113
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.046178680450355586
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04608636926813532
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.046040282898867184
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.045994242615968316
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04585639782485401
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04576473088560213
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04571896615471653
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.04539989189135815
# Solution:       ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2,  Temp: 0.0452185645415899
# Final Solution: ['cheese', 'tomatoes', 'basil', 'peppers'], score: 2
# 4 cheese tomatoes basil peppers
# Execution time: 0.1285994052886963 seconds

# %% [markdown]
# ## Genetic Algorithm

# %%
def generate_population(population_size: int) -> list:
    """Generate a population

    Args:
        population_size (int): Population size

    Returns:
        list: Population
    """
    population = []
    for _ in range(population_size):
        population.append(random_solution())
    return population

def tournament_selection(population: list, tournament_size: int) -> list:
    """Tournament selection

    Args:
        population (list): Population
        tournament_size (int): Tournament size

    Returns:
        list: Selected population
    """
    selected_population = []
    for _ in range(len(population)):
        tournament = random.sample(population, tournament_size)
        winner = max(tournament, key=lambda x: evaluate_solution(x))
        selected_population.append(winner)
    return selected_population

def roulette_selection(population: list) -> list:
    """Roulette selection

    Args:
        population (list): Population

    Returns:
        list: Selected population
    """
    total_fitness = sum(evaluate_solution(individual) for individual in population)
    probabilities = [evaluate_solution(individual) / total_fitness for individual in population]
    selected_population = []
    for _ in range(len(population)):
        selected = random.choices(population, weights=probabilities)[0]
        selected_population.append(selected)
    return selected_population

def single_point_crossover(parent1: set[str], parent2: set[str]) -> tuple:
    """Single point crossover

    Args:
        parent1 (set[str]): Parent 1
        parent2 (set[str]): Parent 2

    Returns:
        tuple: Children
    """
    if len(parent1) <= 1 or len(parent2) <= 1:
        # If either parent has length <= 1, cannot perform crossover
        return parent1, parent2
    
    crossover_point = random.randint(1, min(len(parent1), len(parent2)) - 1)
    
    child1 = list(parent1)[:crossover_point] + list(parent2)[crossover_point:]
    child2 = list(parent2)[:crossover_point] + list(parent1)[crossover_point:]
    
    return set(child1), set(child2)




def mutate(chromosome: set[str], mutation_rate: float = 0.1) ->set[str]:
    """Mutate a chromosome (ingredients on the pizza)

    Args:
        chromosome (set[str]): Set of ingredients on the pizza
        mutation_rate (int): Mutation rate

    Returns:
        set[str]: Mutated chromosome
    """
    mutated_chromosome = set(chromosome)
    for gene in chromosome:
        if random.random() < mutation_rate:
            mutated_chromosome.remove(gene)
    return mutated_chromosome

# %%
def genetic_algorithm(num_iterations: int, population_size: int, crossover_func, mutation_func, log: bool = False):
    population = generate_population(population_size)
    state = population[0] # Initial state
    best_solution = state
    best_score = evaluate_solution(state)
    best_solution_generation = 0 # Generation on which the best solution was found

    generation_num = 0

    print(f"Initial Solution: {state} with score {best_score}")

    while num_iterations > 0:
        generation_num += 1

        tournament_winner_solution = tournament_selection(population, 4)
        roulette_winner_solution = roulette_selection(population)
        
        # Select parents for crossover
        parent1 = random.choice(tournament_winner_solution)
        parent2 = random.choice(roulette_winner_solution)
        
        # Crossover
        offspring1, offspring2 = crossover_func(parent1, parent2)
        
        # Mutation
        offspring1 = mutation_func(offspring1)
        offspring2 = mutation_func(offspring2)
        
        # Replacement
        population.extend([offspring1, offspring2])
        population.sort(key=lambda x: evaluate_solution(x), reverse=True)
        population = population[:population_size]
        
        # Log best solution
        current_best_score = evaluate_solution(population[0])
        if current_best_score > best_score:
            best_solution = population[0]
            best_score = current_best_score
            best_solution_generation = generation_num

        if log:
            print(f"Generation {generation_num}: Best solution: {best_solution} with score {best_score}")

        num_iterations -= 1
    
    print(f"Best solution found at generation {best_solution_generation}: {best_solution} with score {best_score}")
    return best_solution

# %%
print("\nGenetic Algorithm:\n")
start_time = time.time()
final_solution = genetic_algorithm(100, 100, single_point_crossover, mutate, log=True)
end_time = time.time()
print(f"{len(final_solution)} {' '.join(final_solution)}")
print(f"Execution time: {end_time - start_time} seconds")
# Out:
# Genetic Algorithm:
#
# Initial Solution: {'basil', 'peppers', 'pineapple', 'cheese', 'mushrooms'} with score 1
# Generation 1: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 2: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 3: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 4: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 5: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 6: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 7: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 8: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 9: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 10: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 11: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 12: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 13: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 14: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 15: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 16: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 17: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 18: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 19: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 20: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 21: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 22: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 23: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 24: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 25: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 26: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 27: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 28: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 29: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 30: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 31: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 32: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 33: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 34: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 35: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 36: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 37: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 38: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 39: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 40: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 41: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 42: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 43: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 44: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 45: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 46: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 47: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 48: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 49: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 50: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 51: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 52: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 53: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 54: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 55: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 56: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 57: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 58: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 59: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 60: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 61: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 62: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 63: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 64: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 65: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 66: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 67: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 68: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 69: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 70: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 71: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 72: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 73: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 74: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 75: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 76: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 77: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 78: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 79: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 80: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 81: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 82: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 83: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 84: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 85: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 86: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 87: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 88: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 89: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 90: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 91: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 92: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 93: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 94: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 95: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 96: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 97: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 98: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 99: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Generation 100: Best solution: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# Best solution found at generation 1: {'peppers', 'mushrooms', 'cheese', 'tomatoes'} with score 2
# 4 peppers mushrooms cheese tomatoes
# Execution time: 0.213545560836792 seconds
